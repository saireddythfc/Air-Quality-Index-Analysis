# %%
import pandas as pd
import numpy as np
from scipy.special import ndtri
import matplotlib.pyplot as plt

# %%
df2 = pd.read_excel(r'/home/pragya/fyp/abc_median.xlsx')

df2 = df2.sort_values(by=['spm'],ascending=True).reset_index()

df2['count2'] = df2.index + 1

n_rows2 = df2.shape[0]

df2['percentile_area2'] = (df2['count2'])/n_rows2

df2['z_theoritical2'] = ndtri(df2['percentile_area2'])

df2['z_actual2'] = (df2['spm']-df2['spm'].mean())/df2['spm'].std(ddof=0)

df2.head()
# Out:
#    index  Unnamed: 0  year  month  date  so2   no2  rspm    spm  count2  \
# 0    980         980  2010      9     7  4.0  34.0   251  104.0       1
# 1    211         211  2008      7    30  5.0  37.3   251  149.0       2
# 2    955         955  2010      8    13  4.0  36.0   251  158.0       3
# 3    944         944  2010      8     2  4.0  40.0   251  160.0       4
# 4    974         974  2010      9     1  4.0  43.0   251  164.0       5
#
#    percentile_area2  z_theoritical2  z_actual2
# 0          0.000912       -3.117355  -4.733070
# 1          0.001825       -2.906957  -4.136845
# 2          0.002737       -2.777704  -4.017600
# 3          0.003650       -2.682873  -3.991101
# 4          0.004562       -2.607369  -3.938104

# %%
df1 = pd.read_excel(r'/home/pragya/fyp/abc_1.xlsx')

df1 = df1.sort_values(by=['spm'],ascending=True).reset_index()

df1['count1'] = df1.index + 1

n_rows1 = df1.shape[0]

df1['percentile_area1'] = (df1['count1'])/n_rows1

df1['z_theoritical1'] = ndtri(df1['percentile_area1'])

df1['z_actual1'] = (df1['spm']-df1['spm'].mean())/df1['spm'].std(ddof=0)

df1.head()
# Out:
#    index  year  month  date  so2   no2        rspm    spm  count1  \
# 0    980  2010      9     7  4.0  34.0  249.912281  104.0       1
# 1    211  2008      7    30  5.0  37.3  249.912281  149.0       2
# 2    955  2010      8    13  4.0  36.0  249.912281  158.0       3
# 3    944  2010      8     2  4.0  40.0  249.912281  160.0       4
# 4    974  2010      9     1  4.0  43.0  249.912281  164.0       5
#
#    percentile_area1  z_theoritical1  z_actual1
# 0          0.000912       -3.117355  -4.774222
# 1          0.001825       -2.906957  -4.177882
# 2          0.002737       -2.777704  -4.058614
# 3          0.003650       -2.682873  -4.032110
# 4          0.004562       -2.607369  -3.979102

# %%
plt.scatter(df1.z_actual1, df1.z_theoritical1, c="g",alpha = 0.5, marker=r'$\clubsuit$',label="Mean")
plt.scatter(df2.z_actual2, df2.z_theoritical2, c="r", alpha = 0.5, marker='x',label="Median")
plt.plot([-3,-2,-1,0,1,2,3],[-3,-2,-1,0,1,2,3])
