# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_1 = pd.read_excel(r'/home/pragya/fyp/abc_1.xlsx')
df_2 = pd.read_excel(r'/home/pragya/fyp/abc_median.xlsx')

# %%
plt.hist(df_1['no2'])
plt.show()

# %%
plt.hist(df_2['no2'])
plt.show()

# %%
plt.hist(df_1['so2'])
plt.show()

# %%
plt.hist(df_1['spm'])
plt.show()

# %%
plt.hist(df_1['rspm'])
plt.show()

# %%
plt.hist(df_2['so2'])
plt.show()

# %%
plt.hist(df_2['rspm'])
plt.show()

# %%
plt.hist(df_2['spm'])
plt.show()

# %%
df_1.head()
# Out:
#    year  month  date       so2        no2        rspm         spm
# 0  2008      1     1  4.000000  36.500000  131.000000  388.000000
# 1  2008      1     2  4.948598  47.769626  249.912281  464.264151
# 2  2008      1     3  4.948598  47.769626  249.912281  464.264151
# 3  2008      1     4  4.000000  40.700000  164.000000  458.000000
# 4  2008      1     5  4.948598  47.769626  249.912281  464.264151

# %%
ax = df_1.hist(column = ['no2','so2','spm','rspm'],figsize=(12,8),color='#86bf91', zorder=2, rwidth=0.9)
ax = ax[0]
for x in ax:
    x.set_xlabel("Value", labelpad=20, size=10)
    x.set_ylabel("Frequency", labelpad=20, size=10)

# %%
ax = df_2.hist(column = ['no2','so2','spm','rspm'],figsize=(12,8),color='#86bf91', zorder=2, rwidth=0.9)
ax = ax[0]
for x in ax:
    x.set_xlabel("Value", labelpad=20, size=10)
    x.set_ylabel("Frequency", labelpad=20, size=10)
